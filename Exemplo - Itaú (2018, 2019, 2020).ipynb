# %%
from acfe.indices import Indicadores

# %%
filepath = 'Demonstrativos Itau (2018, 2019, 2020).pdf'
s = 'PÁGINA: 1 DE 114'
e = 'PÁGINA: 6 DE 114'
anos = ['2020', '2019', '2018']

# %%
o = Indicadores(filepath, s, e, anos)

# %%
o.estrutura_de_capital()
# Out:
#                                                 2020          2019  \
# Participação de Cappital de Terceiros   9.839039e+00  6.045408e+00
# Composição do Endividamento             2.378589e+01  1.353699e+01
# Imobilização do Patrimônio Líquido      1.007150e+02  9.871451e+01
# Capital Circulante Próprio             -1.883000e+06 -5.030000e+05
# Capital Circulante Líquido              2.417000e+08  2.384000e+08
# Imobilização de Recursos Não Correntes  9.482504e+01  9.441491e+01
#
#                                                 2018
# Participação de Cappital de Terceiros   5.833923e+00
# Composição do Endividamento             1.355300e+01
# Imobilização do Patrimônio Líquido      9.934171e+01
# Capital Circulante Próprio             -6.670000e+05
# Capital Circulante Líquido              2.114000e+08
# Imobilização de Recursos Não Correntes  9.479663e+01

# %%
o.liquidez()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1.01.04'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
o.prazos_medios()
# Out:
#                                             2019        2018       2017
# Prazo Médio de Recebimento de Vendas   29.785559   32.858583  36.182426
# Prazo Médio de Pagamento de Contas    229.359988  226.177619        NaN
# Prazo Médio de Renovação de Estoques   99.283363  101.023572  86.243397
# Giro do Estoque                         3.625985    3.563525   4.174233

# %%
o.rentabilidade()
# Out:
#                                                 2019       2018       2017
# Giro do Ativo                              51.698631  52.480428  53.961060
# Margem Líquida                             23.171862  22.590898  16.258064
# Rentabilidade do Ativo (ROA)               11.979535  11.855800   8.773024
# Rentabilidade do Patrimônio Líquido (ROE)  20.312056  21.537857        NaN

# %%
o.todos()
# Out:
#                                                    2019          2018  \
# Participação de Cappital de Terceiros      6.264297e+01  6.659079e+01
# Composição do Endividamento                6.382492e+01  6.588923e+01
# Imobilização do Patrimônio Líquido         1.184654e+02  1.224813e+02
# Capital Circulante Próprio                -1.156580e+07 -1.293000e+07
# Capital Circulante Líquido                 2.610104e+08  1.206440e+07
# Imobilização de Recursos Não Correntes     8.366271e+01  8.795336e+01
# Liquidez Geral                             9.581496e+01  8.808898e+01
# Liquidez Corrente                          1.104358e+02  1.004786e+02
# Liquidez Seca                              8.653213e+01  7.905051e+01
# Prazo Médio de Recebimento de Vendas       2.978556e+01  3.285858e+01
# Prazo Médio de Pagamento de Contas         2.293600e+02  2.261776e+02
# Prazo Médio de Renovação de Estoques       9.928336e+01  1.010236e+02
# ...
