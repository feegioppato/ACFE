# %%
from acfe import Indicadores

# %% [markdown]
# ## Ambev

# %%
filepath_ambev = 'Demonstrativos Ambev (2018, 2019, 2020).pdf'
s_ambev = 'PÁGINA: 1 DE 182'
e_ambev = 'PÁGINA: 7 DE 182'
anos = ['2020', '2019', '2018']

# %%
ambev = Indicadores(filepath_ambev, s_ambev, e_ambev, anos)

# %%
ambev.estrutura_de_capital()
# Out:
#                                                 2020          2019  \
# Participação de Cappital de Terceiros   6.491860e+01  6.210490e+01
# Composição do Endividamento             4.420906e+01  3.989600e+01
# Imobilização do Patrimônio Líquido      1.468987e+02  1.391892e+02
# Capital Circulante Próprio             -3.462776e+07 -2.509724e+07
# Capital Circulante Líquido             -7.892700e+08 -2.223673e+08
# Imobilização de Recursos Não Correntes  9.498546e+01  9.417419e+01
#
#                                                 2018
# Participação de Cappital de Terceiros   5.959501e+01
# Composição do Endividamento             3.714442e+01
# Imobilização do Patrimônio Líquido      1.388218e+02
# Capital Circulante Próprio             -2.287434e+07
# Capital Circulante Líquido             -1.804517e+08
# Imobilização de Recursos Não Correntes  9.441156e+01

# %%
ambev.liquidez()
# Out:
#                         2020       2019       2018
# Liquidez Geral     54.731082  52.778150  50.034422
# Liquidez Corrente  62.743947  85.354275  85.507265
# Liquidez Seca      48.092062  64.444422  64.594818

# %%
ambev.prazos_medios()
# Out:
#                                             2020        2019       2018
# Prazo Médio de Recebimento de Vendas   21.661019   23.506370  28.180721
# Prazo Médio de Pagamento de Contas    221.225608  190.922243        NaN
# Prazo Médio de Renovação de Estoques   66.235653   81.470355  75.326460
# Giro do Estoque                         5.435139    4.418785   4.779197

# %%
ambev.rentabilidade()
# Out:
#                                                 2020       2019       2018
# Giro do Ativo                              23.132763  26.237365  25.859735
# Margem Líquida                             40.408589  45.198381  47.363435
# Rentabilidade do Ativo (ROA)                9.347623  11.858864  12.248059
# Rentabilidade do Patrimônio Líquido (ROE)  16.846675  20.046563        NaN

# %% [markdown]
# ## Klabin

# %%
filepath_klabin = 'Demonstrativos Klabin (2018, 2019, 2020).pdf'
s_klabin = 'PÁGINA: 1 DE 143'
e_klabin = 'PÁGINA: 7 DE 143'

# %%
klabin = Indicadores(filepath_klabin, s_klabin, e_klabin, anos)

# %%
klabin.todos()
# Out:
#                                                    2020          2019  \
# Participação de Cappital de Terceiros      7.998339e+02  4.626714e+02
# Composição do Endividamento                1.127280e+01  1.129561e+01
# Imobilização do Patrimônio Líquido         6.040418e+02  3.221671e+02
# Capital Circulante Próprio                -2.054079e+07 -1.481644e+07
# Capital Circulante Líquido                 6.499812e+08  1.000056e+09
# Imobilização de Recursos Não Correntes     6.160838e+01  4.910564e+01
# Liquidez Geral                             5.013656e+01  6.744125e+01
# Liquidez Corrente                          2.891949e+02  4.164540e+02
# Liquidez Seca                              2.541501e+02  3.795379e+02
# Prazo Médio de Recebimento de Vendas       3.858839e+01  4.891274e+01
# Prazo Médio de Pagamento de Contas         9.371520e+01  5.122323e+01
# Prazo Médio de Renovação de Estoques       6.099899e+01  6.004873e+01
# ...
